# %% [markdown]
# # 東京の患者と医療の状況

# %%
from ambulance_stats import AmbulanceStats
from patient_stats import PatientStats
from monitoring_tokyo_stats import MonitoringTokyoStats
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1003">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1004">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## 療養者数と病床
#
# source https://www.mhlw.go.jp/stf/seisakunitsuite/newpage_00023.html

# %%
ps = PatientStats()
ps.update()
ps.show('東京都')
# Out:
#   <div class="bk-root" id="4327d25d-d935-414f-a711-1cc297c2d78d" data-root-id="1005"></div>
#   <div class="bk-root" id="a5886e29-b290-4229-8ab6-43e3b4d1b798" data-root-id="1290"></div>
#   <div class="bk-root" id="91ec6f09-1a8b-48e1-aeb8-1facc0d13087" data-root-id="1600"></div>
#   <div class="bk-root" id="934bb8b6-5b1f-4455-ab98-603eda0d7ed1" data-root-id="1984"></div>
#   <div class="bk-root" id="a9e7c12e-aef4-491a-b23c-1b55ebd325fb" data-root-id="2446"></div>

# %% [markdown]
# ## 救急車の搬送困難事案
#
# source https://www.fdma.go.jp/disaster/coronavirus/post-1.html

# %%
amb = AmbulanceStats()
amb.areas[:3]
# Out:
# ['札幌市消防局', '青森地域広域事務組合消防本部', '盛岡地区広域消防組合消防本部']

# %%
amb.show('東京消防庁')
# Out:
#   <div class="bk-root" id="9fd629ef-34ca-42f6-b959-c0ecba06be73" data-root-id="2790"></div>

# %% [markdown]
# ## 東京都のサンプリング調査における陽性率
#
# source https://www.fukushihoken.metro.tokyo.lg.jp/iryo/kansen/kensa/kensuu.html

# %%
MonitoringTokyoStats().show()
# Out:
#   <div class="bk-root" id="86532d06-8ae0-48b9-af03-433d6efb1d7f" data-root-id="3098"></div>
#   <div class="bk-root" id="69507db6-4b27-4767-88df-0303cb3f3f3f" data-root-id="3435"></div>
