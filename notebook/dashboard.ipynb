# %%
import util
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
amb = util.AmbulanceStats('data/coronavirus_data.xlsx')
amb.areas[:3]
# Out:
# ['札幌市消防局', '青森地域広域事務組合消防本部', '盛岡地区広域消防組合消防本部']

# %%
amb.show('東京消防庁')
# Out:
#   <div class="bk-root" id="272af641-8f3a-4a00-b15c-f2b5eb7ca345" data-root-id="1182"></div>
